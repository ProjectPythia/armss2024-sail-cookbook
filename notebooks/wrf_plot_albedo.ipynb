# %%
### WRF Data ###
# plot albedo for January 2022 cases #

import xarray as xr
import cartopy
import cartopy.crs as ccrs
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plot differences in albedo 
dataset_25 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-25.nc')
dataset_30 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-30.nc')
mean_dataset_diff = dataset_30.mean(dim="Time") - dataset_25.mean(dim="Time")
mean_dataset_diff.ALBEDO.plot(x='south_north',y='west_east')

# %%
plt.figure(figsize=(10, 4));
matplotlib.rcParams.update({'font.size': 14});
ax = plt.axes(projection=ccrs.Robinson());
mean_dataset = dataset.mean(dim="Time")
mean_dataset.ALBEDO.plot.pcolormesh(ax=ax, transform=ccrs.PlateCarree(),add_labels=False, 
                                 cbar_kwargs={'label': r"Albedo"});
ax.coastlines();
plt.tight_layout();

# %%
dataset_25.mean(dim="Time").ALBEDO.plot(x='south_north',y='west_east')

# %%
dataset_30.mean(dim="Time").ALBEDO.plot(x='south_north',y='west_east')

# %%
# Plot differences in albedo 
dataset_25 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-25.nc')
dataset_26 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-26.nc')
mean_dataset_diff = dataset_26.mean(dim="Time") - dataset_25.mean(dim="Time")
mean_dataset_diff.ALBEDO.plot(x='south_north',y='west_east')

# %%
# Plot differences in albedo 
dataset_25 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-25.nc')
dataset_27 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-27.nc')
mean_dataset_diff = dataset_27.mean(dim="Time") - dataset_25.mean(dim="Time")
mean_dataset_diff.ALBEDO.plot(x='south_north',y='west_east')

# %%
# Plot differences in albedo 
dataset_25 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-25.nc')
dataset_28 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-28.nc')
mean_dataset_diff = dataset_28.mean(dim="Time") - dataset_25.mean(dim="Time")
mean_dataset_diff.ALBEDO.plot(x='south_north',y='west_east')

# %%
# Plot differences in albedo 
dataset_25 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-25.nc')
dataset_29 = xr.open_mfdataset('wrf_data/jan_2022/wrfhourly_d03_2022-01-29.nc')
mean_dataset_diff = dataset_29.mean(dim="Time") - dataset_25.mean(dim="Time")
mean_dataset_diff.ALBEDO.plot(x='south_north',y='west_east')
